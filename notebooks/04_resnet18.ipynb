# %% [markdown]
# # ResNet-18 - Individual Baseline Run

# %%
import sys
import os

import torch

sys.path.append(os.path.abspath("../src"))

from models import ResNet18
from data import prepare_full_dataframe, prepare_data
from train import run_training_pipeline, run_smoke_test
from utils import (
    get_device,
    print_model_overrides,
)
import config

print(f"Python:         {sys.executable}")
print(f"PyTorch:        {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU:            {torch.cuda.get_device_name(0)}")
# Out:
# Python:         c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Scripts\python.exe
# PyTorch:        2.11.0+cu128
# CUDA available: True
# GPU:            NVIDIA GeForce RTX 5090 Laptop GPU

# %%
dataset_path = config.DATASET_PATH
print("Dataset location:", dataset_path)

metadata_file = os.path.join(dataset_path, "Data_Entry_2017.csv")
df = prepare_full_dataframe(metadata_file, dataset_path)

print(f"Total images:    {len(df)}")
print(f"Unique patients: {df['Patient ID'].nunique()}")
# Out:
# Dataset location: C:\Users\profb\PROJECTS\datasets\NIH_Chest_X-Rays
# Total images:    112120
# Unique patients: 30805

# %%
print(df["split"].value_counts())
# Out:
# split
# train    78934
# val      16874
# test     16312
# Name: count, dtype: int64

# %%
train_loader, val_loader, test_loader = prepare_data(df, model_name="ResNet18")
print("Train transforms:", train_loader.dataset.transform)
device = get_device()
# Out:
# Using CUDA (GPU)

# %% [markdown]
# ## Smoke Test

# %%
run_smoke_test(
    model_name="ResNet18",
    model_builder=lambda: ResNet18(num_classes=2, in_channels=1),
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    device=device,
    live_plot=False,
)
# Out:
# === Smoke test: ResNet18 (epochs=1, patience=1, batches=1) ===
#
# === Training ResNet18 ===
#
# === Run Configuration ===
# Model: ResNet18
# Training: epochs=1, patience=1, batch_size=256, image_size=256, seed=42
# Precision/Memory: amp_enabled=True, amp_dtype=bf16, channels_last(global=True, override=None, effective=True)
# Optimization: layerwise_lr_enabled=True, uses_param_groups=True, freeze_backbone_enabled=True, freeze_backbone_epochs=1, lr=0.0001, backbone_lr=5e-05, head_lr=0.0002, weight_decay=5e-05, label_smoothing=0.03
# Scheduler: enabled=True, type=warmup_cosine, start_epoch=1, warmup_epochs=0, warmup_start_factor=0.4, cosine_t_max=1, min_lr=1e-06, steps_per_epoch=1
# Checkpoint Resume: False
# Model Overrides: {'backbone_lr': 5e-05, 'head_lr': 0.0002, 'freeze_backbone_epochs': 1}
# Starting fresh training (resume disabled): c:\Users\profb\PROJECTS\cxr-model-benchmark\outputs\checkpoints\best_resnet18\latest.pt
# AMP enabled (bf16, grad scaler: off)
# channels_last enabled
# Scheduler active: type=warmup_cosine, start_epoch=1, steps_per_epoch=1, cosine_t_max=1
# Train Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s]
#   VRAM a/r/p: 0.12G(0.5%)/1.66G(6.9%)/1.23G(5.2%)
# Val Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1/1 | ETA (Remaining): 00:00:00 | Total ETA: 00:00:04
#   Train Loss: 0.7215 | Train Acc: 0.4688
#   Val Loss: 0.8754 | Val Acc: 0.4648
#   Val Precision: 0.4648
#   Val Recall: 1.0000 | Val F1: 0.6347
#   Val AUPRC: 0.4449
#   Backbone LR: 1e-06 | Head LR: 1e-06
#   Optimizer: AdamW | Weight Decay: 5e-05 | No-Decay Groups: 2
# ------------------------------------------------------------
# Saved best model to c:\Users\profb\PROJECTS\cxr-model-benchmark\outputs\models\best_resnet18.pt
# ------------------------------------------------------------
# Test:   0%|          | 0/1 [00:00<?, ?it/s]
# ({'model': 'ResNet18',
#   'epochs': 1,
#   'batch_size': 256,
#   'image_size': 256,
#   'test_loss': 0.8122525215148926,
#   'accuracy': 0.515625,
#   'precision': 0.5176470588235295,
#   'recall': 0.9924812030075187,
#   'f1': 0.6804123711340206,
#   'auprc': 0.555107000579395},
#  {'train_loss': [0.7214595675468445],
#   'train_acc': [0.46875],
#   'val_loss': [0.8753742575645447],
#   'val_acc': [0.46484375],
#   'val_precision': [0.46484375],
#   'val_recall': [1.0],
#   'val_f1': [0.6346666666666667],
#   'val_auprc': [0.4448631004366326],
#   'lr': [1e-06],
#   'lr_backbone': [1e-06],
#   'lr_head': [1e-06],
#   'backbone_frozen': [True],
#   'vram_peak_pct': [5.152440368062422],
#   'best_epoch': 1})

# %% [markdown]
# ## Training

# %%
### Function Definitions
# Out:
# === Training ResNet18 ===
#
# === Run Configuration ===
# Model: ResNet18
# Training: epochs=30, patience=5, batch_size=256, image_size=256, seed=42
# Precision/Memory: amp_enabled=True, amp_dtype=bf16, channels_last(global=True, override=None, effective=True)
# Optimization: layerwise_lr_enabled=True, uses_param_groups=True, freeze_backbone_enabled=True, freeze_backbone_epochs=1, lr=0.0001, backbone_lr=5e-05, head_lr=0.0002, weight_decay=5e-05, label_smoothing=0.03
# Scheduler: enabled=True, type=warmup_cosine, start_epoch=1, warmup_epochs=1, warmup_start_factor=0.4, cosine_t_max=29, min_lr=1e-06, steps_per_epoch=1
# Checkpoint Resume: True
# Model Overrides: {'backbone_lr': 5e-05, 'head_lr': 0.0002, 'freeze_backbone_epochs': 1}
# Starting fresh training (checkpoint completed): c:\Users\profb\PROJECTS\cxr-model-benchmark\outputs\checkpoints\best_resnet18\latest.pt
# AMP enabled (bf16, grad scaler: off)
# channels_last enabled
# Scheduler active: type=warmup_cosine, start_epoch=1, steps_per_epoch=1, cosine_t_max=29
# Train Epoch 1:   0%|          | 0/309 [00:14<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 metrics, history = run_training_pipeline(
#       2     model_name="ResNet18",
#       3     model_builder=lambda: ResNet18(num_classes=2, in_channels=1),
#       4     train_loader=train_loader,
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\src\train.py:67, in run_training_pipeline(model_name, model_builder, train_loader, val_loader, test_loader, device, live_plot, resume_from_checkpoint)
#      64 save_name = f"best_{model_name.lower().replace('-', '_')}"
#      65 checkpoint_path = get_training_checkpoint_path(save_name)
# ---> 67 history = train_model(
#      68     model=model,
#      69     train_loader=train_loader,
#      70     val_loader=val_loader,
#      71     criterion=criterion,
#      72     optimizer=optimizer,
#      73     scheduler=scheduler,
#      74     training_control=training_control,
#      75     device=device,
#      76     save_name=save_name,
#      77     checkpoint_path=checkpoint_path,
#      78     resume_from_checkpoint=resume_from_checkpoint,
#      79     patience=int(training_control.get("patience", config.PATIENCE)),
#      80     live_plot=live_plot,
#      81     live_plot_model_name=model_name,
#      82 )
#      84 save_path = get_model_path(save_name)
#      85 model.load_state_dict(torch.load(save_path, map_location=device))
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\src\train_eval.py:1005, in train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, training_control, device, save_name, checkpoint_path, resume_from_checkpoint, patience, live_plot, live_plot_model_name)
#    1002     else:
#    1003         print(f"Epoch {epoch + 1}: backbone unfrozen, fine-tuning all layers.")
# -> 1005 train_loss, train_acc, train_vram_pct = train_one_epoch(
#    1006     model, train_loader, criterion, optimizer, device,
#    1007     epoch=epoch,
#    1008     start_time=start_time,
#    1009     total_epochs=config.NUM_EPOCHS,
#    1010     use_amp=use_amp,
#    1011     amp_dtype=amp_dtype,
#    1012     grad_scaler=grad_scaler,
#    1013     use_channels_last=use_channels_last,
#    1014 )
#    1016 val_loss, val_acc, val_precision, val_recall, val_f1, val_labels, val_preds, val_probs = evaluate(
#    1017     model, val_loader, criterion, device,
#    1018     epoch=epoch,
#    (...)   1022     use_channels_last=use_channels_last,
#    1023 )
#    1025 history["train_loss"].append(train_loss)
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\src\train_eval.py:744, in train_one_epoch(model, loader, criterion, optimizer, device, epoch, start_time, total_epochs, use_amp, amp_dtype, grad_scaler, use_channels_last)
#     741 if show_vram:
#     742     torch.cuda.reset_peak_memory_stats(device)
# --> 744 for batch_idx, (images, labels) in enumerate(progress_bar):
#     745     transfer_non_blocking = _is_cuda_device(device)
#     746     images = _move_images_to_device(
#     747         images,
#     748         device,
#     749         transfer_non_blocking=transfer_non_blocking,
#     750         use_channels_last=use_channels_last,
#     751     )
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\torch\utils\data\dataloader.py:497, in DataLoader.__iter__(self)
#     495         self._iterator = self._get_iterator()
#     496     else:
# --> 497         self._iterator._reset(self)
#     498     return self._iterator
#     499 else:
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1286, in _MultiProcessingDataLoaderIter._reset(self, loader, first_iter)
#    1284 resume_iteration_cnt = self._num_workers
#    1285 while resume_iteration_cnt > 0:
# -> 1286     return_idx, return_data = self._get_data()
#    1287     if isinstance(return_idx, _utils.worker._ResumeIteration):
#    1288         if return_data is not None:
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1473, in _MultiProcessingDataLoaderIter._get_data(self)
#    1471 elif self._pin_memory:
#    1472     while self._pin_memory_thread.is_alive():
# -> 1473         success, data = self._try_get_data()
#    1474         if success:
#    1475             return data
#
# File c:\Users\profb\PROJECTS\cxr-model-benchmark\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1297 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1298     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1299     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1307     # Returns a 2-tuple:
#    1308     #   (bool: whether successfully get data, any: data if successful else None)
#    1309     try:
# -> 1310         data = self._data_queue.get(timeout=timeout)
#    1311         return (True, data)
#    1312     except Exception as e:
#    1313         # At timeout and error, we manually check whether any worker has
#    1314         # failed. Note that this is the only mechanism for Windows to detect
#    1315         # worker failures.
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\queue.py:210, in Queue.get(self, block, timeout)
#     208 if remaining <= 0.0:
#     209     raise Empty
# --> 210 self.not_empty.wait(remaining)
#     211 if self.is_shutdown and not self._qsize():
#     212     raise ShutDown
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\threading.py:373, in Condition.wait(self, timeout)
#     371 else:
#     372     if timeout > 0:
# --> 373         gotit = waiter.acquire(True, timeout)
#     374     else:
#     375         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# run_results = []
# baseline_auprc = 0.650
#
# from notebook_experiment_runner import (
#     cleanup_training_artifacts,
#     print_planned_run_configuration,
#     run_seed_experiment,
# )

# %% [markdown]
# seed_bank = tuple(config.TUNING_OVERRIDES.get("ResNet18", {}).get("seed_bank", [16, 32, 64]))
# epoch_log_file = "../outputs/experiment_outputs/resnet18_epoch_metrics.log"
#
# def run_resnet_experiment(seeds=seed_bank, live_plot=True, reset_results=False, reset_epoch_log=True):
#     run_seed_experiment(
#         run_results=run_results,
#         baseline_auprc=baseline_auprc,
#         model_builder=lambda: ResNet18(num_classes=2, in_channels=1),
#         train_loader=train_loader,
#         val_loader=val_loader,
#         test_loader=test_loader,
#         device=device,
#         model_name="ResNet18",
#         seeds=seeds,
#         live_plot=live_plot,
#         reset_results=reset_results,
#         epoch_log_file=epoch_log_file,
#         reset_epoch_log=reset_epoch_log,
#     )

# %%
### Run
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 baseline_auprc = 0.686
#       2
# ----> 3 best_epoch = history.get('best_epoch')
#       4 if best_epoch is not None:
#       5     idx = best_epoch - 1  # Convert epoch (1-indexed) to array index (0-indexed)
#       6
#
# NameError: name 'history' is not defined

# %% [markdown]
# print_planned_run_configuration(
#     model_name="ResNet18",
#     model_builder=lambda: ResNet18(num_classes=2, in_channels=1),
#     device=device,
#     resume_from_checkpoint=False,
# )

# %%
run_resnet_experiment()
# Out:
# === Test Results ===
# Best Epoch:  9
# Loss:        0.6267
# Accuracy:    0.6668
# Precision:   0.6551
# Recall:      0.5890
# F1:          0.6203
# AUPRC:       0.6564

# %%
## Complete Metrics
# Out:
# Val:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
import pandas as pd

summary_df = pd.DataFrame([
    {
        "Seed": r["seed"],
        "Best Epoch": r["best_epoch"],
        "Best Val AUPRC": f"{r['best_val_auprc']:.4f}" if r['best_val_auprc'] else "N/A",
        "Delta": f"{r['delta']:.4f}" if r['delta'] else "N/A",
    }
    for r in run_results
])

print("\n=== Run Comparison ===")
print(summary_df.to_string(index=False))

if len(run_results) > 1:
    valid_auprc = [r["best_val_auprc"] for r in run_results if r["best_val_auprc"] is not None]
    valid_best_epochs = [r["best_epoch"] for r in run_results if r["best_epoch"] is not None]
    mean_auprc = sum(valid_auprc) / len(valid_auprc)
    mean_delta = sum(r["delta"] for r in run_results if r["delta"] is not None) / len(valid_auprc)
    mean_best_epoch = sum(valid_best_epochs) / len(valid_best_epochs)
    std_auprc = (sum((x - mean_auprc) ** 2 for x in valid_auprc) / len(valid_auprc)) ** 0.5
    print(f"\nMean Best Epoch: {mean_best_epoch:.2f}")
    print(f"Mean Val AUPRC: {mean_auprc:.4f} ({mean_delta:+.4f})")
    print(f"Std Dev: {std_auprc:.4f}")
# Out:
# Image path:       C:\Users\profb\PROJECTS\datasets\NIH_Chest_X-Rays\images_007\images\00014015_015.png
# True label:       abnormal
# Predicted class:  abnormal
# Probabilities:    {'normal': 0.36441972851753235, 'abnormal': 0.6355802416801453}
